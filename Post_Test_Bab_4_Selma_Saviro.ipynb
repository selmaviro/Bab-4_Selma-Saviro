# %% [markdown]
# <a href="https://colab.research.google.com/github/selmaviro/Bab-4_Selma-Saviro/blob/main/Post_Test_Bab_4_Selma_Saviro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Halo, Selma")
# Out:
# Halo, Selma
